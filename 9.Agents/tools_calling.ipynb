# %% [markdown]
# Calling a tool by LLM.

# %% [markdown]
# LLM = brain ,,
# Tools = haath–pair

# %%
from langchain_groq  import ChatGroq
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
# tool create

@tool
def multiply(a: int, b: int) -> int:
  """Given 2 numbers a and b this tool returns their product"""
  return a * b

# %% [markdown]
# #tool Binding.

# %%
llm = ChatGroq( model="openai/gpt-oss-20b")
llm.invoke("hii")
# Out:
# AIMessage(content='Hello! 👋 How can I help you today?', additional_kwargs={'reasoning_content': 'User says "hii". Probably wants greeting. We\'ll respond friendly.'}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 73, 'total_tokens': 108, 'completion_time': 0.038817033, 'completion_tokens_details': {'reasoning_tokens': 15}, 'prompt_time': 0.004964198, 'prompt_tokens_details': None, 'queue_time': 0.155512622, 'total_time': 0.043781231}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_a8c584dda7', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019bf4bd-ccdf-7f01-86d3-fba5b283be7f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 73, 'output_tokens': 35, 'total_tokens': 108, 'output_token_details': {'reasoning': 15}})

# %%
llm_with_tools = llm.bind_tools([multiply])
